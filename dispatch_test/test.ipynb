# %%
from datascience import *
import numpy as np
# import glob
import pandas as pd
% matplotlib inline

# %%
dispatch = Table.read_table('temp.csv')
wra = Table.read_table('../WRA/combined.csv')
# Out:
# /opt/conda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2821: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
dispatch
# Out:
# Last Name | First Name | Middle Name | Age  | Date of Departure | Camp Name  | Destination              | Occupation            | Gender | Marital Status | Source               | Notes
# Yoshihara | Takeo      | nan         | nan  | nan               | Tule Lake  | Rupert, Idaho            | nan                   | nan    | nan            | Tulean Dispatch 5.1b | Also mentioned in TD 5.4
# Honda     | Noboru     | nan         | nan  | nan               | Tule Lake  | New York, New York       | Student               | nan    | nan            | Tulean Dispatch 5.2  | Rochdale Institute
# Sakamoto  | Fumi       | nan         | nan  | nan               | Tule Lake  | New York, New York       | Student               | nan    | nan            | Tulean Dispatch 5.2  | Rochdale Institute; a letter of hers is conveyed in TD 5.5
# Ota       | Robert     | nan         | nan  | nan               | Tule Lake  | New York, New York       | Student               | nan    | nan            | Tulean Dispatch 5.2  | Rochdale Institute
# Kajikawa  | Eideo      | nan         | nan  | nan               | Tule Lake  | Camp Shelby, Mississippi | Military              | nan    | nan            | Tulean Dispatch 5.2  | nan
# Ishihara  | Peggy      | nan         | nan  | nan               | Gila River | Chicago, Illinois        | Factory               | nan    | nan            | Tulean Dispatch 5.2  | nan
# Sumida    | George     | nan         | nan  | nan               | Tule Lake  | Ann Arbor, Michigan      | Gas Station Attendant | nan    | nan            | Tulean Dispatch 5.2  | nan
# Yanagawa  | Josie      | S.          | nan  | nan               | Tule Lake  | Camp Robinson, Arkansas  | nan                   | nan    | nan            | Tulean Dispatch 5.2  | nan
# Furushiro | Midori     | nan         | nan  | March 22, 1943    | Tule Lake  | Caldwell, Idaho          | nan                   | nan    | nan            | Tulean Dispatch 5.2  | nan
# Yamagiwa  | Yuri       | nan         | nan  | nan               | Tule Lake  | Palatine, Illinois       | nan                   | nan    | nan            | Tulean Dispatch 5.2  | nan
# ... (16 rows omitted)

# %%
wra.where('RELOCATION PROJECT', 'Tule Lake').where('LAST NAME', 'YOSHIHARA').where('FIRST NAME', 'TAKEO')
# Out:
# Unnamed: 0 | LAST NAME | FIRST NAME | MIDDLE INITIAL | RELOCATION PROJECT | ASSEMBLY CENTER | LAST PERMANENT ADDRESS | LAST PERMANENT ADDRESS STATE | LAST PERMANENT ADDRESS COUNTY | LAST PERMANENT ADDRESS POPULATION DENSITY | BIRTH PLACE OF PARENTS     | FATHERS OCCUPATION IN U.S.          | FATHERS OCCUPATION ABROAD  | TOTAL YEARS OF SCHOOLING IN JAPAN | YEARS OF SCHOOLING IN JAPAN | EDUCATIONAL DEGREES                     | YEAR OF FIRST ARRIVAL IN TERRITORIAL U.S. | TOTAL LENGTH OF TIME IN JAPAN | NUMBER OF TIMES IN JAPAN    | AGE AT TIME IN JAPAN | MILITARY AND NAVAL SERVICE, PUBLIC ASSISTANCE AND PENSIONS, PHYSICAL DEFECTS | INDIVIDUAL NUMBER | SEX AND MARITAL STATUS | RACE OF INDIVIDUAL AND SPOUSE  | YEAR OF BIRTH | BIRTH PLACE                 | ALIEN REGISTRATION NUMBER, SOCIAL SECURITY NUMBER AND JAPANESE LANGUAGE SCHOOL | HIGHEST GRADE COMPLETED OR GRADE ATTENDING | LANGUAGE                                         | RELIGION     | PRIMARY OCCUPATION | SECONDARY OCCUPATION | TERTIARY OCCUPATION | POTENTIAL OCCUPATION 1     | POTENTIAL OCCUPATION 2              | FILE NUMBER | BLANK 1
# 957        | YOSHIHARA | TAKEO      | nan            | Tule Lake          | Pinedale        | TACOMA, WASHINGTON     | Pacific States - Washington  | PIERCE                        | 25,000 - 999,999                          | Father=Japan, Mother=Japan | MANAGERIAL & OFFICIAL (EXCEPT FARM) | BLANK, UNKNOWN, NONE, DASH | NONE                              | NONE                        | BACHELORS-SOCIAL SCIENCES & MATHEMATICS | --                                        | NONE                          | NONE-- NOT ATTENDING SCHOOL | NEVER IN JAPAN       | MASKED VALUE                                                                 | 19414A            | MALE SINGLE            | INDIVIDUAL-JAPANESE; NO SPOUSE | 18            | Pacific States - Washington | HAS NEITHER A.R. NOR S. S. NUMBER AND HAS ATTENDED JAPANESE LANGUAGE SCHOOL    | COLLEGE 4 IN U.S.                          | JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE | MASKED VALUE | Retail Managers    | nan                  | nan                 | Social and Welfare Workers | Buyers and Department Heads, Stores | 414012      | 31171

# %%
def find_names(source, dest):
    for row in source.rows:
        print(row[1])
find_names(dispatch, wra)
# Out:
# Takeo
# Noboru
# Fumi
# Robert
# Eideo
# Peggy
# George
# Josie
# Midori
# Yuri
# Sumi
# Joe
# Yuri
# Toko
# Tom
# Mrs. Tom
# Mrs. Chiyo
# Patsy
# Minnie
# Sumi
# Esther
# George
# Mike
# Ray
# Don
# Jean

# %%
dispatch = pd.read_csv('temp.csv')
wra = pd.read_csv('../WRA/combined.csv')
# Out:
# /opt/conda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Uppercase the columns of interest
dispatch = dispatch.rename(columns={'Last Name': 'LAST NAME', 'First Name': 'FIRST NAME', 'Camp Name':'RELOCATION PROJECT'})

# %%
# dispatch['LAST NAME'] = map(lambda x: x.upper(), dispatch['LAST NAME'])
# dispatch['FIRST NAME'] = map(lambda x: x.upper(), dispatch['FIRST NAME'])
# for name in dispatch['FIRST NAME']:
#     print(name.upper())
for col_name in ['FIRST NAME', 'LAST NAME']:
    dispatch[col_name] = dispatch[col_name].apply((lambda x: x.upper()))

dispatch
#map(lambda x: x.upper(), dispatch['FIRST NAME'])
# Out:
#     LAST NAME  FIRST NAME Middle Name  Age Date of Departure  \
# 0   YOSHIHARA       TAKEO         NaN  NaN               NaN
# 1       HONDA      NOBORU         NaN  NaN               NaN
# 2    SAKAMOTO        FUMI         NaN  NaN               NaN
# 3         OTA      ROBERT         NaN  NaN               NaN
# 4    KAJIKAWA       EIDEO         NaN  NaN               NaN
# 5    ISHIHARA       PEGGY         NaN  NaN               NaN
# 6      SUMIDA      GEORGE         NaN  NaN               NaN
# 7    YANAGAWA       JOSIE          S.  NaN               NaN
# 8   FURUSHIRO      MIDORI         NaN  NaN    March 22, 1943
# 9    YAMAGIWA        YURI         NaN  NaN               NaN
# 10       HAJI        SUMI         NaN  NaN               NaN
# 11    OKAMOTO         JOE         NaN  NaN               NaN
# 12   KOBUKATA        YURI         NaN  NaN    March 24, 1943
# 13      FUJII        TOKO         NaN  NaN               NaN
# 14      OGURA         TOM         NaN  NaN               NaN
# 15      OGURA    MRS. TOM         NaN  NaN               NaN
# 16      OGURA  MRS. CHIYO         NaN  NaN               NaN
# 17      OGURA       PATSY         NaN  NaN               NaN
# 18      OGURA      MINNIE         NaN  NaN               NaN
# 19      OGURA        SUMI         NaN  NaN               NaN
# 20      OGURA      ESTHER         NaN  NaN               NaN
# 21     NOMURA      GEORGE         NaN  NaN               NaN
# 22   HIRAHARA        MIKE         NaN  NaN               NaN
# 23      YASUI         RAY   "Choppie"  NaN               NaN
# 24       NORO         DON         NaN  NaN               NaN
# 25      AKITA        JEAN         NaN  NaN               NaN
#
#    RELOCATION PROJECT               Destination             Occupation  \
# 0           Tule Lake             Rupert, Idaho                    NaN
# 1           Tule Lake        New York, New York                Student
# 2           Tule Lake        New York, New York                Student
# 3           Tule Lake        New York, New York                Student
# 4           Tule Lake  Camp Shelby, Mississippi               Military
# 5          Gila River         Chicago, Illinois                Factory
# 6           Tule Lake       Ann Arbor, Michigan  Gas Station Attendant
# 7           Tule Lake   Camp Robinson, Arkansas                    NaN
# 8           Tule Lake           Caldwell, Idaho                    NaN
# 9           Tule Lake        Palatine, Illinois                    NaN
# 10          Tule Lake          Washington, D.C.                    NaN
# 11          Tule Lake           Omaha, Nebraska                    NaN
# 12          Tule Lake    Minneapolis, Minnesota                    NaN
# 13          Tule Lake                       NaN                    NaN
# 14          Tule Lake            Eastern Oregon                    NaN
# 15          Tule Lake            Eastern Oregon                    NaN
# 16          Tule Lake            Eastern Oregon                    NaN
# 17          Tule Lake            Eastern Oregon                    NaN
# 18          Tule Lake            Eastern Oregon                    NaN
# 19          Tule Lake            Eastern Oregon                    NaN
# 20          Tule Lake            Eastern Oregon                    NaN
# 21          Tule Lake          Peoria, Illinois    Boilerman, Hospital
# 22          Tule Lake          Peoria, Illinois   Laundryman, Hospital
# 23          Tule Lake      Great Falls, Montana      Sugar Beet Farmer
# 24          Tule Lake      Great Falls, Montana      Sugar Beet Farmer
# 25          Tule Lake      Great Falls, Montana      Sugar Beet Farmer
#
#     Gender  Marital Status                Source  \
# 0      NaN             NaN  Tulean Dispatch 5.1b
# 1      NaN             NaN   Tulean Dispatch 5.2
# 2      NaN             NaN   Tulean Dispatch 5.2
# 3      NaN             NaN   Tulean Dispatch 5.2
# 4      NaN             NaN   Tulean Dispatch 5.2
# 5      NaN             NaN   Tulean Dispatch 5.2
# 6      NaN             NaN   Tulean Dispatch 5.2
# 7      NaN             NaN   Tulean Dispatch 5.2
# 8      NaN             NaN   Tulean Dispatch 5.2
# 9      NaN             NaN   Tulean Dispatch 5.2
# 10     NaN             NaN   Tulean Dispatch 5.2
# 11     NaN             NaN   Tulean Dispatch 5.2
# 12     NaN             NaN   Tulean Dispatch 5.3
# 13     NaN             NaN   Tulean Dispatch 5.3
# 14     NaN             NaN   Tulean Dispatch 5.4
# 15     NaN             NaN   Tulean Dispatch 5.4
# 16     NaN             NaN   Tulean Dispatch 5.4
# 17     NaN             NaN   Tulean Dispatch 5.4
# 18     NaN             NaN   Tulean Dispatch 5.4
# 19     NaN             NaN   Tulean Dispatch 5.4
# 20     NaN             NaN   Tulean Dispatch 5.4
# 21     NaN             NaN   Tulean Dispatch 5.8
# 22     NaN             NaN   Tulean Dispatch 5.8
# 23     NaN             NaN   Tulean Dispatch 5.8
# 24     NaN             NaN   Tulean Dispatch 5.8
# 25     NaN             NaN   Tulean Dispatch 5.8
#
#                                                 Notes
# 0                            Also mentioned in TD 5.4
# 1                                  Rochdale Institute
# 2   Rochdale Institute; a letter of hers is convey...
# 3                                  Rochdale Institute
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  Wife of Tom Ogura, first name not given; Ogura...
# 16  Ogura family; not sure if Chiyo is her husband...
# 17                                       Ogura family
# 18                                       Ogura family
# 19                                       Ogura family
# 20                                       Ogura family
# 21                                                NaN
# 22                                                NaN
# 23                  Mentioned as a part of 49 farmers
# 24                  Mentioned as a part of 49 farmers
# 25                  Mentioned as a part of 49 farmers

# %%
merged = pd.merge(dispatch, wra, on = ['LAST NAME', 'FIRST NAME', 'RELOCATION PROJECT'])
merged
# Out:
#     LAST NAME FIRST NAME Middle Name  Age Date of Departure  \
# 0   YOSHIHARA      TAKEO         NaN  NaN               NaN
# 1       HONDA     NOBORU         NaN  NaN               NaN
# 2    SAKAMOTO       FUMI         NaN  NaN               NaN
# 3         OTA     ROBERT         NaN  NaN               NaN
# 4      SUMIDA     GEORGE         NaN  NaN               NaN
# 5      SUMIDA     GEORGE         NaN  NaN               NaN
# 6    YANAGAWA      JOSIE          S.  NaN               NaN
# 7   FURUSHIRO     MIDORI         NaN  NaN    March 22, 1943
# 8    YAMAGIWA       YURI         NaN  NaN               NaN
# 9     OKAMOTO        JOE         NaN  NaN               NaN
# 10   KOBUKATA       YURI         NaN  NaN    March 24, 1943
# 11      OGURA      PATSY         NaN  NaN               NaN
# 12      OGURA     MINNIE         NaN  NaN               NaN
# 13      OGURA       SUMI         NaN  NaN               NaN
# 14      OGURA     ESTHER         NaN  NaN               NaN
# 15     NOMURA     GEORGE         NaN  NaN               NaN
# 16     NOMURA     GEORGE         NaN  NaN               NaN
# 17   HIRAHARA       MIKE         NaN  NaN               NaN
# 18      YASUI        RAY   "Choppie"  NaN               NaN
# 19      AKITA       JEAN         NaN  NaN               NaN
#
#    RELOCATION PROJECT              Destination             Occupation  Gender  \
# 0           Tule Lake            Rupert, Idaho                    NaN     NaN
# 1           Tule Lake       New York, New York                Student     NaN
# 2           Tule Lake       New York, New York                Student     NaN
# 3           Tule Lake       New York, New York                Student     NaN
# 4           Tule Lake      Ann Arbor, Michigan  Gas Station Attendant     NaN
# 5           Tule Lake      Ann Arbor, Michigan  Gas Station Attendant     NaN
# 6           Tule Lake  Camp Robinson, Arkansas                    NaN     NaN
# 7           Tule Lake          Caldwell, Idaho                    NaN     NaN
# 8           Tule Lake       Palatine, Illinois                    NaN     NaN
# 9           Tule Lake          Omaha, Nebraska                    NaN     NaN
# 10          Tule Lake   Minneapolis, Minnesota                    NaN     NaN
# 11          Tule Lake           Eastern Oregon                    NaN     NaN
# 12          Tule Lake           Eastern Oregon                    NaN     NaN
# 13          Tule Lake           Eastern Oregon                    NaN     NaN
# 14          Tule Lake           Eastern Oregon                    NaN     NaN
# 15          Tule Lake         Peoria, Illinois    Boilerman, Hospital     NaN
# 16          Tule Lake         Peoria, Illinois    Boilerman, Hospital     NaN
# 17          Tule Lake         Peoria, Illinois   Laundryman, Hospital     NaN
# 18          Tule Lake     Great Falls, Montana      Sugar Beet Farmer     NaN
# 19          Tule Lake     Great Falls, Montana      Sugar Beet Farmer     NaN
#
#     Marital Status   ...           HIGHEST GRADE COMPLETED OR GRADE ATTENDING  \
# 0              NaN   ...                                    COLLEGE 4 IN U.S.
# 1              NaN   ...                                 ELEMENTARY 8 IN U.S.
# 2              NaN   ...                                    COLLEGE 2 IN U.S.
# 3              NaN   ...                                    COLLEGE 4 IN U.S.
# 4              NaN   ...                                HIGH SCHOOL 1 IN U.S.
# 5              NaN   ...                                HIGH SCHOOL 4 IN U.S.
# 6              NaN   ...                                HIGH SCHOOL 4 IN U.S.
# 7              NaN   ...                                HIGH SCHOOL 4 IN U.S.
# 8              NaN   ...                                HIGH SCHOOL 4 IN U.S.
# 9              NaN   ...                                HIGH SCHOOL 4 IN U.S.
# 10             NaN   ...                                    COLLEGE 1 IN U.S.
# 11             NaN   ...    NO SCHOOLING OR KINDERGARTEN IN EITHER JAPAN O...
# 12             NaN   ...                                HIGH SCHOOL 4 IN U.S.
# 13             NaN   ...                                    COLLEGE 1 IN U.S.
# 14             NaN   ...                                 ELEMENTARY 5 IN U.S.
# 15             NaN   ...                                HIGH SCHOOL 4 IN U.S.
# 16             NaN   ...                                HIGH SCHOOL 1 IN U.S.
# 17             NaN   ...                                HIGH SCHOOL 4 IN U.S.
# 18             NaN   ...                                    COLLEGE 2 IN U.S.
# 19             NaN   ...                                    COLLEGE 2 IN U.S.
#
#                                              LANGUAGE      RELIGION  \
# 0    JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 1   JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 2    JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 3    JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 4   JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 5    JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 6   JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 7    JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 8   JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 9   JAPANESE SPEAKING; ENGLISH SPEAK, READ & WRITE...  MASKED VALUE
# 10                    ENGLISH SPEAK, WRITE, READ ONLY  MASKED VALUE
# 11                 NOT APPLICABLE (11 YRS. AND UNDER)  MASKED VALUE
# 12  JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 13  JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 14                 NOT APPLICABLE (11 YRS. AND UNDER)  MASKED VALUE
# 15  JAPANESE SPEAKING; ENGLISH SPEAK, READ & WRITE...  MASKED VALUE
# 16  JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 17                    ENGLISH SPEAK, WRITE, READ ONLY  MASKED VALUE
# 18   JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 19                    ENGLISH SPEAK, WRITE, READ ONLY  MASKED VALUE
#
#                                    PRIMARY OCCUPATION  \
# 0                                     Retail Managers
# 1                                 Salesmen, Insurance
# 2                                     Retail Managers
# 3                              Crop Specialty Farmers
# 4       Waiters and Waitresses, Except Private Family
# 5            Boarding-House and Lodging-House Keepers
# 6                                        Sales Clerks
# 7                            Stenographer and Typists
# 8                           Farm Managers and Foremen
# 9   Semiskilled Chauffeurs and Drivers, Bus, Taxi,...
# 10                                     Maids, General
# 11                                                NaN
# 12                                       Sales Clerks
# 13                              Farm Hands, Vegetable
# 14                                                NaN
# 15                                      Truck Farmers
# 16  Semiskilled Occupations in Laundering, Cleanin...
# 17  Semiskilled Chauffeurs and Drivers, Bus, Taxi,...
# 18                                      Fruit Farmers
# 19                                       Sales Clerks
#
#                                  SECONDARY OCCUPATION  \
# 0                                                 NaN
# 1                      Managers and Officials, N.E.C.
# 2                                           Designers
# 3                                  Wholesale Managers
# 4                                   Farm Hands, Fruit
# 5                                        Sales Clerks
# 6                                      Maids, General
# 7                                     Cooks, Domestic
# 8   Semiskilled Chauffeurs and Drivers, Bus, Taxi,...
# 9             Semiskilled Apprentices to Other Trades
# 10                                     Undefined Code
# 11                                                NaN
# 12                                     Maids, General
# 13                                       Sales Clerks
# 14                                                NaN
# 15                                                NaN
# 16     Bookkeepers and Cashiers, Except Bank Cashiers
# 17  Skilled Inspectors, Scalers, and Graders, Logs...
# 18                                                NaN
# 19                Managerial and Official Occupations
#
#                                TERTIARY OCCUPATION  \
# 0                                              NaN
# 1                        Farm Managers and Foremen
# 2                     Personal Service Occupations
# 3                               Post Office Clerks
# 4                                              NaN
# 5                                    Ship Stewards
# 6                                              NaN
# 7    Maids and Housemen, Hotels, Restaurants, Etc.
# 8                                              NaN
# 9   Skilled Mechanics and Repairmen, Motor Vehicle
# 10                                             NaN
# 11                                             NaN
# 12                           Farm Hands, Vegetable
# 13            Skilled Dressmakers and Seamstresses
# 14                                             NaN
# 15                                             NaN
# 16         Semiskilled Sawmill Occupations, N.E.C.
# 17                                             NaN
# 18                                             NaN
# 19                                             NaN
#
#                                POTENTIAL OCCUPATION 1  \
# 0                          Social and Welfare Workers
# 1                                  Skilled Carpenters
# 2               Barbers, Beauticians, and Manicurists
# 3                 Managerial and Official Occupations
# 4                     Musicians and Teachers of Music
# 5      Skilled Mechanics and Repairmen, Motor Vehicle
# 6   Semiskilled Occupations in Manufacture of Knit...
# 7            Semiskilled Dressmakers and Seamstresses
# 8            Semiskilled Dressmakers and Seamstresses
# 9                                                 NaN
# 10           Semiskilled Dressmakers and Seamstresses
# 11                                                NaN
# 12                    Musicians and Teachers of Music
# 13                    Musicians and Teachers of Music
# 14                    Musicians and Teachers of Music
# 15  Semiskilled Chauffeurs and Drivers, Bus, Taxi,...
# 16                                 Skilled Carpenters
# 17  Athletes, Sports Instructors, and Sports Offic...
# 18                 Inspectors, Public Service, N.E.C.
# 19                   Professional Occupations, N.E.C.
#
#                                POTENTIAL OCCUPATION 2 FILE NUMBER BLANK 1
# 0                 Buyers and Department Heads, Stores      414012   31171
# 1                                                 NaN      414345   51081
# 2                                     Cooks, Domestic      407623   41151
# 3                                                 NaN      400632   31171
# 4                Semiprofessional Occupations, N.E.C.      405330   21092
# 5                             Fishermen and Oystermen      408396   51121
# 6                                                 NaN      412640   31121
# 7   Unskilled Occupations in Manufacture of Leathe...      400663   41121
# 8                          Social and Welfare Workers      413598   31121
# 9                                                 NaN      405361   41121
# 10                           Stenographer and Typists      413159   21142
# 11                                                NaN      403357   13001
# 12           Semiskilled Dressmakers and Seamstresses      403351   31122
# 13  Skillled Occupations in Manufacture of Knit Goods      403352   31142
# 14                                                NaN      403354   11051
# 15                  Library Assistants and Attendants      413634   41122
# 16                                                NaN      414573   51092
# 17                    Musicians and Teachers of Music      400665   31121
# 18                            Fishermen and Oystermen      404625   41152
# 19               Skilled Dressmakers and Seamstresses      412874   31151
#
# [20 rows x 46 columns]

# %%
def check_duplicate(tabl, first_name, last_name):
    query = tabl[tabl['FIRST NAME'] == first_name and tabl['LAST NAME'] == last_name]
    num_rows = len(query.index)
    print('{} {} in {} rows'.format(first_name, last_name, num_rows))
apply()
