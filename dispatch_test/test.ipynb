# %%
from datascience import *
import numpy as np
# import glob
import pandas as pd
% matplotlib inline

# %% [markdown]
# ### A little dive into pandas

# %%
dispatch = pd.read_csv('tuleandispatch.csv')
wra = pd.read_csv('../WRA/combined.csv')
# Out:
# /opt/conda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dispatch['Camp Name'].unique() # How should we clean the data to reconcile this?
# Out:
# array(['TULE LAKE', 'Tule Lake', 'Gila River', 'Tule 38603-A',
#        'Tule Lake  3803-A', 'Tule Lake 2418-B', 'Tule Lake 5413-F',
#        ' Tule Lake 1307-A', 'Tule Lake ', 'Santa Fe, Mexico', nan], dtype=object)

# %%
# Some Data Cleaning to match with WRA Dataset
# Uppercase the columns of interest
dispatch = dispatch.rename(columns={'Last Name': 'LAST NAME', 'First Name': 'FIRST NAME', 'Camp Name':'RELOCATION PROJECT', 'Destination': 'DESTINATION'})
# Make First name and last name values uppercase
for col_name in ['FIRST NAME', 'LAST NAME']:
    dispatch[col_name] = dispatch[col_name].apply((lambda x: str(x).upper()))

dispatch
# Out:
#       Age RELOCATION PROJECT Date of Departure                 DESTINATION  \
# 0     NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 1     NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 2     NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 3     NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 4     NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 5     NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 6     NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 7     NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 8     NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 9     NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 10    NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 11    NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 12    NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 13    NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 14    NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 15    NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 16    NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 17    NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 18    NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 19    NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 20    NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 21    NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 22    NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 23    NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 24    NaN          TULE LAKE        05/26/1943                SHAKOPEE, MN
# 25    NaN          TULE LAKE        06/08/1943                 CHICAGO, IL
# 26    NaN          TULE LAKE        06/08/1943                 CHICAGO, IL
# 27    NaN          TULE LAKE        05/31/1943                   LOGAN, UT
# 28    NaN          TULE LAKE        05/31/1943                   BOISE, ID
# 29    NaN          TULE LAKE        05/31/1943                 CHICAGO, IL
# ..    ...                ...               ...                         ...
# 429   NaN          Tule Lake     July 22, 1943             Ontario, Oregon
# 430   NaN          Tule Lake     July 22, 1943             Ontario, Oregon
# 431   NaN          Tule Lake     July 22, 1943             Ontario, Oregon
# 432   NaN          Tule Lake     July 22, 1943             Ontario, Oregon
# 433   NaN          Tule Lake     July 22, 1943           Chicago, Illinois
# 434   NaN          Tule Lake     July 22, 1943           Chicago, Illinois
# 435   NaN          Tule Lake     July 22, 1943           Chicago, Illinois
# 436   NaN          Tule Lake     July 22, 1943           Chicago, Illinois
# 437   NaN          Tule Lake     July 22, 1943           Chicago, Illinois
# 438   NaN          Tule Lake     July 22, 1943            Denver, Colorado
# 439   NaN          Tule Lake     July 22, 1943            Denver, Colorado
# 440   NaN          Tule Lake     July 22, 1943            Denver, Colorado
# 441   NaN          Tule Lake     July 22, 1943      Minneapolis, Minnesota
# 442   NaN          Tule Lake     July 22, 1943      Minneapolis, Minnesota
# 443   NaN          Tule Lake     July 22, 1943          Rockford, Illinois
# 444   NaN          Tule Lake     July 22, 1943          Rockford, Illinois
# 445   NaN          Tule Lake     July 22, 1943            Gering, Nebraska
# 446   NaN          Tule Lake     July 22, 1943         St. Paul, Minnesota
# 447   NaN          Tule Lake     July 22, 1943               Gary, Indiana
# 448   NaN          Tule Lake     July 22, 1943          New York, New York
# 449   NaN          Tule Lake     July 22, 1943             Lamar, Colorado
# 450   NaN          Tule Lake          9/6/1943  Colorado Springs, Colorado
# 451   NaN          Tule Lake          9/6/1943  Colorado Springs, Colorado
# 452   NaN          Tule Lake          9/6/1943  Colorado Springs, Colorado
# 453   NaN          Tule Lake          9/6/1943  Colorado Springs, Colorado
# 454   NaN          Tule Lake          9/6/1943  Colorado Springs, Colorado
# 455  70.0          Tule Lake               NaN                   (Unknown)
# 456   NaN          Tule Lake         9/24/1943                    New York
# 457   NaN          Tule Lake         9/24/1943                    New York
# 458   NaN          Tule Lake         9/24/1943                    New York
#
#     FIRST NAME Gender   LAST NAME Marital Status Middle Name  \
# 0       GEORGE      M    SAKAMOTO            NaN         NaN
# 1       ALBERT      M      OSHITA            NaN         NaN
# 2       THOMAS      M      OSHIKA            NaN         A.
# 3        HENRY      M   SHIHOJIMA            NaN         NaN
# 4          TOM      M      MURAKI            NaN         NaN
# 5      HISASHI      M     KUNAGAI            NaN         NaN
# 6         JACK      M       CKUDA            NaN          V.
# 7         SHIG      M        KATO            NaN         NaN
# 8        KUNIO      M      KAWATA            NaN        BILL
# 9          BOB      M     OKAMURA            NaN         NaN
# 10         JOE      M       FUJIL            NaN         NaN
# 11       FRANK      M      FUKAMI            NaN          K.
# 12         TED      M       OKITA            NaN          T.
# 13        JONE      M     KOSHIBA            NaN         NaN
# 14    YAMAMOTO      M   YOSHIYUKI            NaN         NaN
# 15       KAMEO      M      FUJIYE            NaN         NaN
# 16         BEN      M      SUMADA            NaN          T.
# 17      KEIRJI      M     YOSHINO            NaN         NaN
# 18        TOKI      M      YOKOTA            NaN     CHARLES
# 19         BEN      M     ISALOKE            NaN         NaN
# 20      LESTER      M      KIYONO            NaN         NaN
# 21       FUMIO      M      HAMGAI            NaN         NaN
# 22        GLEN      M   YOSHIZUMI            NaN         NaN
# 23       JAMES      M    TAKEMOTO            NaN         NaN
# 24         ROY      M   YAMAGUCHI            NaN         NaN
# 25    TSUYOSHI      M     NAKMURA            NaN         NaN
# 26        BILL      M       OSUGA            NaN         NaN
# 27         TOM      M      INUKAI            NaN         NaN
# 28      FUMIKO      M      INUKAI            NaN         NaN
# 29    PENELOPE      F        YABE            NaN          F.
# ..         ...    ...         ...            ...         ...
# 429     ALFRED    NaN       NITTA            NaN         NaN
# 430     HAJIME    NaN    HAMAMOTO            NaN         NaN
# 431      HARRY    NaN   HIGASHIRO            NaN         NaN
# 432        ROY    NaN   HIGASHIRO            NaN         NaN
# 433      GOHEI    NaN      TANAKA            NaN         NaN
# 434     YASUNO    NaN      TANAKA            NaN         NaN
# 435    YOSHIKO    NaN      TANAKA            NaN         NaN
# 436       TARO    NaN    TAKEMURA            NaN        Paul
# 437      FRANK    NaN      FUJITA            NaN           T
# 438       TOSA    NaN    KUMASAKA            NaN         NaN
# 439       YUJI    NaN    KUMASAKA            NaN         NaN
# 440      YUKIO    NaN     KUASAKA            NaN         NaN
# 441     YOSHIE    NaN         DOI            NaN         NaN
# 442     TOYOKO    NaN     YOSHIDA            NaN         NaN
# 443       SUMI    NaN   KOBAYASHI            NaN         NaN
# 444      AKIRA    NaN      HIRATA            NaN         NaN
# 445      SADAO    NaN     DAIRIKI            NaN         NaN
# 446     SUMIKO    NaN      YOKOTA            NaN         NaN
# 447      ASAKO    NaN       SHIMA            NaN         NaN
# 448    SAKAUYE    NaN       OKUBO            NaN         NaN
# 449      NAOKO    NaN     HOSHINO            NaN         NaN
# 450     YORIJE    NaN  SUGASAWARA            NaN         NaN
# 451        AME    NaN  SUGASAWARA            NaN         NaN
# 452      SAKAE    NaN  SUGASAWARA            NaN         NaN
# 453      SAKAI    NaN      OSHITA            NaN         NaN
# 454     TERUKO    NaN      OSHITA            NaN         NaN
# 455    MINIOWA    NaN        KUNO            NaN         NaN
# 456  SHIGAICHI    NaN        KUBO            NaN         NaN
# 457    "GORKY"    NaN    KAWASAKI            NaN         NaN
# 458     WILBUR    NaN   TAKEGUCHI            NaN         NaN
#
#                                                  Notes  \
# 0                   NYA WAR PRODUCTION TRAINING CENTER
# 1                   NYA WAR PRODUCTION TRAINING CENTER
# 2                   NYA WAR PRODUCTION TRAINING CENTER
# 3    NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 4    NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 5    NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 6    NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 7    NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 8    NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 9    NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 10   NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 11   NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 12   NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 13   NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 14   NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 15   NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 16   NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 17   NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 18   NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 19   NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 20   NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 21   NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 22   NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 23   NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 24   NYA WAR PRODUCTION TRAINING CENTER, project ca...
# 25                                        AKA, 'TOOTS'
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 429                                                NaN
# 430                                                NaN
# 431                                                NaN
# 432                                                NaN
# 433                                                NaN
# 434                                                NaN
# 435                                                NaN
# 436                                                NaN
# 437                                                NaN
# 438                                                NaN
# 439                                                NaN
# 440                                                NaN
# 441                                                NaN
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
# 447                                                NaN
# 448                                                NaN
# 449                                                NaN
# 450                                                NaN
# 451                                                NaN
# 452                                                NaN
# 453                                                NaN
# 454                                                NaN
# 455                                                NaN
# 456                                                NaN
# 457                                                NaN
# 458                                                NaN
#
#                                             Occupation                 Source
# 0    MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 1    MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 2    MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 3    MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 4    MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 5    MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 6    MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 7    MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 8    MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 9    MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 10   MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 11   MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 12   MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 13   MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 14   MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 15   MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 16   MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 17   MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 18   MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 19   MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 20   MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 21   MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 22   MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 23   MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 24   MACHINERY , SHEET METAL, WELDING, FOUNDRY, PAT...  TULEAN DISPATCH, 5.58
# 25                                     EDITOR IN CHIEF  TULEAN DISPATCH, 5.67
# 26                                     RESEARCH EDITOR  TULEAN DISPATCH, 5.67
# 27                                                 NaN  TULEAN DISPATCH, 5.67
# 28                                                 NaN  TULEAN DISPATCH, 5.67
# 29                                                 NaN  TULEAN DISPATCH, 5.67
# ..                                                 ...                    ...
# 429                                                NaN    Tulean Dispatch 6.5
# 430                                                NaN    Tulean Dispatch 6.5
# 431                                                NaN    Tulean Dispatch 6.5
# 432                                                NaN    Tulean Dispatch 6.5
# 433                                                NaN    Tulean Dispatch 6.5
# 434                                                NaN    Tulean Dispatch 6.5
# 435                                                NaN    Tulean Dispatch 6.5
# 436                                                NaN    Tulean Dispatch 6.5
# 437                                                NaN    Tulean Dispatch 6.5
# 438                                                NaN    Tulean Dispatch 6.5
# 439                                                NaN    Tulean Dispatch 6.5
# 440                                                NaN    Tulean Dispatch 6.5
# 441                                                NaN    Tulean Dispatch 6.5
# 442                                                NaN    Tulean Dispatch 6.5
# 443                                                NaN    Tulean Dispatch 6.5
# 444                                                NaN    Tulean Dispatch 6.5
# 445                                                NaN    Tulean Dispatch 6.5
# 446                                                NaN    Tulean Dispatch 6.5
# 447                                                NaN    Tulean Dispatch 6.5
# 448                                                NaN    Tulean Dispatch 6.5
# 449                                                NaN    Tulean Dispatch 6.5
# 450                                                NaN                    NaN
# 451                                                NaN                    NaN
# 452                                                NaN                    NaN
# 453                                                NaN                    NaN
# 454                                                NaN                    NaN
# 455                                                NaN                    NaN
# 456                                                NaN                    NaN
# 457                                                NaN                    NaN
# 458                                                NaN                    NaN
#
# [459 rows x 12 columns]

# %%
# Merging with WRA
merged = pd.merge(dispatch, wra, on = ['LAST NAME', 'FIRST NAME', 'RELOCATION PROJECT'])
merged
# Out:
#       Age RELOCATION PROJECT Date of Departure  \
# 0     NaN          Tule Lake               NaN
# 1     NaN          Tule Lake               NaN
# 2     NaN          Tule Lake          7/5/1943
# 3     NaN          Tule Lake               NaN
# 4     NaN          Tule Lake               NaN
# 5     NaN          Tule Lake               NaN
# 6     NaN          Tule Lake               NaN
# 7     NaN          Tule Lake               NaN
# 8     NaN          Tule Lake    March 22, 1943
# 9     NaN          Tule Lake               NaN
# 10    NaN          Tule Lake               NaN
# 11    NaN          Tule Lake    March 24, 1943
# 12    NaN          Tule Lake               NaN
# 13    NaN          Tule Lake               NaN
# 14    NaN          Tule Lake               NaN
# 15    NaN          Tule Lake               NaN
# 16    NaN          Tule Lake               NaN
# 17    NaN          Tule Lake               NaN
# 18    NaN          Tule Lake               NaN
# 19    NaN          Tule Lake               NaN
# 20    NaN          Tule Lake               NaN
# 21    NaN          Tule Lake      May13th,1943
# 22    NaN          Tule Lake    Sept. 16, 1942
# 23    NaN          Tule Lake    Sept. 19, 1942
# 24   20.0          Tule Lake    Sept. 12, 1942
# 25    NaN          Tule Lake    Sept. 12, 1942
# 26    NaN          Tule Lake    Sept. 12, 1942
# 27    NaN          Tule Lake         6/28/1943
# 28    NaN          Tule Lake         6/28/1943
# 29    NaN          Tule Lake         6/29/1943
# ..    ...                ...               ...
# 229   NaN          Tule Lake     July 19, 1943
# 230   NaN          Tule Lake     July 19, 1943
# 231   NaN          Tule Lake     July 19, 1943
# 232   NaN          Tule Lake     July 19, 1943
# 233   NaN          Tule Lake               NaN
# 234   NaN          Tule Lake     July 20, 1943
# 235   NaN          Tule Lake     July 20, 1943
# 236   NaN          Tule Lake     July 21, 1943
# 237   NaN          Tule Lake     July 21, 1943
# 238   NaN          Tule Lake     July 21, 1943
# 239   NaN          Tule Lake     July 21, 1943
# 240   NaN          Tule Lake     July 21, 1943
# 241   NaN          Tule Lake     July 22, 1943
# 242   NaN          Tule Lake     July 22, 1943
# 243   NaN          Tule Lake     July 22, 1943
# 244   NaN          Tule Lake     July 22, 1943
# 245   NaN          Tule Lake     July 22, 1943
# 246   NaN          Tule Lake     July 22, 1943
# 247   NaN          Tule Lake     July 22, 1943
# 248   NaN          Tule Lake     July 22, 1943
# 249   NaN          Tule Lake     July 22, 1943
# 250   NaN          Tule Lake     July 22, 1943
# 251   NaN          Tule Lake     July 22, 1943
# 252   NaN          Tule Lake     July 22, 1943
# 253   NaN          Tule Lake     July 22, 1943
# 254   NaN          Tule Lake     July 22, 1943
# 255   NaN          Tule Lake     July 22, 1943
# 256   NaN          Tule Lake     July 22, 1943
# 257   NaN          Tule Lake     July 22, 1943
# 258   NaN          Tule Lake          9/6/1943
#
#                                       DESTINATION FIRST NAME Gender  \
# 0                                   Rupert, Idaho      TAKEO    NaN
# 1                              New York, New York     NOBORU    NaN
# 2                           Des Plaines, Illinois     NOBORU    NaN
# 3                              New York, New York       FUMI    NaN
# 4                              New York, New York     ROBERT    NaN
# 5                             Ann Arbor, Michigan     GEORGE    NaN
# 6                             Ann Arbor, Michigan     GEORGE    NaN
# 7                         Camp Robinson, Arkansas      JOSIE    NaN
# 8                                 Caldwell, Idaho     MIDORI    NaN
# 9                              Palatine, Illinois       YURI    NaN
# 10                                Omaha, Nebraska        JOE    NaN
# 11                         Minneapolis, Minnesota       YURI    NaN
# 12                                 Eastern Oregon      PATSY    NaN
# 13                                 Eastern Oregon     MINNIE    NaN
# 14                                 Eastern Oregon       SUMI    NaN
# 15                                 Eastern Oregon     ESTHER    NaN
# 16                               Peoria, Illinois     GEORGE    NaN
# 17                               Peoria, Illinois     GEORGE    NaN
# 18                               Peoria, Illinois       MIKE    NaN
# 19                           Great Falls, Montana        RAY    NaN
# 20                           Great Falls, Montana       JEAN    NaN
# 21                        Ft. Leavenworth, Kansas       JOHN      M
# 22               Hamilton Valley County, Montana        PAUL      M
# 23                     Plaacer County, California        TOM      M
# 24                                    Ogdon, Utah       FRED      M
# 25                                    Ogdon, Utah       MIKE      M
# 26                                    Ogdon, Utah        KAY      M
# 27                       Camp Shelby, Mississippi      TOSHI    NaN
# 28                         Minneapolis, Minnesota      FRANK   Male
# 29   Great Northern Railroad, Spokane, Washington     JUNIUS    NaN
# ..                                            ...        ...    ...
# 229                           Widow Rock, Arizona     MASAKO    NaN
# 230                              Cincinnati, Ohio      MASAO    NaN
# 231                           St. Clair, Michigan      TUFFY    NaN
# 232                              Denver, Colorado      EMIKO    NaN
# 233                          Camp Grant, Illinois     GEORGE    NaN
# 234                                   Hunt, Idaho    KANJIRO    NaN
# 235                                   Hunt, Idaho     YUKIKO    NaN
# 236                                  Boise, Idaho     GEORGE    NaN
# 237                                  Boise, Idaho     GEORGE    NaN
# 238                                  Boise, Idaho    YOSHIMI    NaN
# 239                                  Boise, Idaho        JOE    NaN
# 240                                  Boise, Idaho        JOE    NaN
# 241                               Ontario, Oregon     DICKIE    NaN
# 242                               Ontario, Oregon    FRANCIS    NaN
# 243                               Ontario, Oregon     ALFRED    NaN
# 244                               Ontario, Oregon     HAJIME    NaN
# 245                             Chicago, Illinois      GOHEI    NaN
# 246                             Chicago, Illinois     YASUNO    NaN
# 247                             Chicago, Illinois    YOSHIKO    NaN
# 248                             Chicago, Illinois       TARO    NaN
# 249                             Chicago, Illinois      FRANK    NaN
# 250                             Chicago, Illinois      FRANK    NaN
# 251                              Denver, Colorado       TOSA    NaN
# 252                        Minneapolis, Minnesota     TOYOKO    NaN
# 253                            Rockford, Illinois      AKIRA    NaN
# 254                              Gering, Nebraska      SADAO    NaN
# 255                           St. Paul, Minnesota     SUMIKO    NaN
# 256                                 Gary, Indiana      ASAKO    NaN
# 257                               Lamar, Colorado      NAOKO    NaN
# 258                    Colorado Springs, Colorado     TERUKO    NaN
#
#      LAST NAME Marital Status Middle Name  \
# 0    YOSHIHARA            NaN         NaN
# 1        HONDA            NaN         NaN
# 2        HONDA            NaN         NaN
# 3     SAKAMOTO            NaN         NaN
# 4          OTA            NaN         NaN
# 5       SUMIDA            NaN         NaN
# 6       SUMIDA            NaN         NaN
# 7     YANAGAWA            NaN          S.
# 8    FURUSHIRO            NaN         NaN
# 9     YAMAGIWA            NaN         NaN
# 10     OKAMOTO            NaN         NaN
# 11    KOBUKATA            NaN         NaN
# 12       OGURA            NaN         NaN
# 13       OGURA            NaN         NaN
# 14       OGURA            NaN         NaN
# 15       OGURA            NaN         NaN
# 16      NOMURA            NaN         NaN
# 17      NOMURA            NaN         NaN
# 18    HIRAHARA            NaN         NaN
# 19       YASUI            NaN   "Choppie"
# 20       AKITA            NaN         NaN
# 21        KUBO              S         NaN
# 22     HAYASHI              S         NaN
# 23        YEGO              S         NaN
# 24    DODOBARA              S         NaN
# 25    FUJISHIN              S         NaN
# 26    FUJISHIN              S         NaN
# 27        KUGE            NaN         NaN
# 28    ISHIKAWA            NaN         NaN
# 29   MATSUMOTO            NaN         NaN
# ..         ...            ...         ...
# 229     ISHIDA            NaN         NaN
# 230      INADA            NaN         NaN
# 231     YASUDA            NaN           H
# 232   FUJIMOTO            NaN         NaN
# 233  NISHIKAWA            NaN         NaN
# 234     SUZUKI            NaN         NaN
# 235     SUZUKI            NaN         NaN
# 236      MIYAI            NaN         NaN
# 237      MIYAI            NaN         NaN
# 238   ISHIMOTO            NaN         NaN
# 239     TOMITA            NaN         NaN
# 240     TOMITA            NaN         NaN
# 241   MORIYASU            NaN         NaN
# 242     SUZUKI            NaN          M.
# 243      NITTA            NaN         NaN
# 244   HAMAMOTO            NaN         NaN
# 245     TANAKA            NaN         NaN
# 246     TANAKA            NaN         NaN
# 247     TANAKA            NaN         NaN
# 248   TAKEMURA            NaN        Paul
# 249     FUJITA            NaN           T
# 250     FUJITA            NaN           T
# 251   KUMASAKA            NaN         NaN
# 252    YOSHIDA            NaN         NaN
# 253     HIRATA            NaN         NaN
# 254    DAIRIKI            NaN         NaN
# 255     YOKOTA            NaN         NaN
# 256      SHIMA            NaN         NaN
# 257    HOSHINO            NaN         NaN
# 258     OSHITA            NaN         NaN
#
#                                                  Notes   ...    \
# 0                             Also mentioned in TD 5.4   ...
# 1                                   Rochdale Institute   ...
# 2                                                  NaN   ...
# 3    Rochdale Institute; a letter of hers is convey...   ...
# 4                                   Rochdale Institute   ...
# 5                                                  NaN   ...
# 6                                                  NaN   ...
# 7                                                  NaN   ...
# 8                                                  NaN   ...
# 9                                                  NaN   ...
# 10                                                 NaN   ...
# 11                                                 NaN   ...
# 12                                        Ogura family   ...
# 13                                        Ogura family   ...
# 14                                        Ogura family   ...
# 15                                        Ogura family   ...
# 16                                                 NaN   ...
# 17                                                 NaN   ...
# 18                                                 NaN   ...
# 19                   Mentioned as a part of 49 farmers   ...
# 20                   Mentioned as a part of 49 farmers   ...
# 21                                     Millitary Leave   ...
# 22                                         Labor leave   ...
# 23                                        Supply Leave   ...
# 24                                         Labor leave   ...
# 25                                         Labor leave   ...
# 26                                         Labor leave   ...
# 27                                                 NaN   ...
# 28                                                 NaN   ...
# 29                                                 NaN   ...
# ..                                                 ...   ...
# 229                                                NaN   ...
# 230                                                NaN   ...
# 231                                                NaN   ...
# 232                                                NaN   ...
# 233                                                NaN   ...
# 234                                                NaN   ...
# 235                                                NaN   ...
# 236                                                NaN   ...
# 237                                                NaN   ...
# 238                                                NaN   ...
# 239                                                NaN   ...
# 240                                                NaN   ...
# 241                                                NaN   ...
# 242                                                NaN   ...
# 243                                                NaN   ...
# 244                                                NaN   ...
# 245                                                NaN   ...
# 246                                                NaN   ...
# 247                                                NaN   ...
# 248                                                NaN   ...
# 249                                                NaN   ...
# 250                                                NaN   ...
# 251                                                NaN   ...
# 252                                                NaN   ...
# 253                                                NaN   ...
# 254                                                NaN   ...
# 255                                                NaN   ...
# 256                                                NaN   ...
# 257                                                NaN   ...
# 258                                                NaN   ...
#
#             HIGHEST GRADE COMPLETED OR GRADE ATTENDING  \
# 0                                    COLLEGE 4 IN U.S.
# 1                                 ELEMENTARY 8 IN U.S.
# 2                                 ELEMENTARY 8 IN U.S.
# 3                                    COLLEGE 2 IN U.S.
# 4                                    COLLEGE 4 IN U.S.
# 5                                HIGH SCHOOL 1 IN U.S.
# 6                                HIGH SCHOOL 4 IN U.S.
# 7                                HIGH SCHOOL 4 IN U.S.
# 8                                HIGH SCHOOL 4 IN U.S.
# 9                                HIGH SCHOOL 4 IN U.S.
# 10                               HIGH SCHOOL 4 IN U.S.
# 11                                   COLLEGE 1 IN U.S.
# 12   NO SCHOOLING OR KINDERGARTEN IN EITHER JAPAN O...
# 13                               HIGH SCHOOL 4 IN U.S.
# 14                                   COLLEGE 1 IN U.S.
# 15                                ELEMENTARY 5 IN U.S.
# 16                               HIGH SCHOOL 4 IN U.S.
# 17                               HIGH SCHOOL 1 IN U.S.
# 18                               HIGH SCHOOL 4 IN U.S.
# 19                                   COLLEGE 2 IN U.S.
# 20                                   COLLEGE 2 IN U.S.
# 21                              HIGH SCHOOL 5 IN JAPAN
# 22                               HIGH SCHOOL 3 IN U.S.
# 23                               HIGH SCHOOL 4 IN U.S.
# 24                               HIGH SCHOOL 2 IN U.S.
# 25                               HIGH SCHOOL 4 IN U.S.
# 26                               HIGH SCHOOL 4 IN U.S.
# 27            POST GRADUATE OR COLL. 5 OR MORE IN U.S.
# 28                               HIGH SCHOOL 1 IN U.S.
# 29                               HIGH SCHOOL 4 IN U.S.
# ..                                                 ...
# 229           POST GRADUATE OR COLL. 5 OR MORE IN U.S.
# 230                                  COLLEGE 2 IN U.S.
# 231                              HIGH SCHOOL 2 IN U.S.
# 232                              HIGH SCHOOL 4 IN U.S.
# 233                               ELEMENTARY 5 IN U.S.
# 234                             HIGH SCHOOL 4 IN JAPAN
# 235                              HIGH SCHOOL 4 IN U.S.
# 236                              HIGH SCHOOL 4 IN U.S.
# 237                              HIGH SCHOOL 4 IN U.S.
# 238                              HIGH SCHOOL 4 IN U.S.
# 239                                  COLLEGE 1 IN U.S.
# 240                               ELEMENTARY 1 IN U.S.
# 241                              HIGH SCHOOL 4 IN U.S.
# 242                              HIGH SCHOOL 3 IN U.S.
# 243                              HIGH SCHOOL 4 IN U.S.
# 244                              HIGH SCHOOL 4 IN U.S.
# 245                              ELEMENTARY 8 IN JAPAN
# 246                              ELEMENTARY 8 IN JAPAN
# 247                              HIGH SCHOOL 3 IN U.S.
# 248                                  COLLEGE 2 IN U.S.
# 249                              HIGH SCHOOL 4 IN U.S.
# 250                               ELEMENTARY 8 IN U.S.
# 251                             HIGH SCHOOL 1 IN JAPAN
# 252                              HIGH SCHOOL 4 IN U.S.
# 253                              HIGH SCHOOL 4 IN U.S.
# 254                              HIGH SCHOOL 2 IN U.S.
# 255                              HIGH SCHOOL 4 IN U.S.
# 256                              HIGH SCHOOL 4 IN U.S.
# 257           POST GRADUATE OR COLL. 5 OR MORE IN U.S.
# 258                                  COLLEGE 1 IN U.S.
#
#                                               LANGUAGE      RELIGION  \
# 0     JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 1    JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 2    JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 3     JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 4     JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 5    JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 6     JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 7    JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 8     JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 9    JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 10   JAPANESE SPEAKING; ENGLISH SPEAK, READ & WRITE...  MASKED VALUE
# 11                     ENGLISH SPEAK, WRITE, READ ONLY  MASKED VALUE
# 12                  NOT APPLICABLE (11 YRS. AND UNDER)  MASKED VALUE
# 13   JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 14   JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 15                  NOT APPLICABLE (11 YRS. AND UNDER)  MASKED VALUE
# 16   JAPANESE SPEAKING; ENGLISH SPEAK, READ & WRITE...  MASKED VALUE
# 17   JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 18                     ENGLISH SPEAK, WRITE, READ ONLY  MASKED VALUE
# 19    JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 20                     ENGLISH SPEAK, WRITE, READ ONLY  MASKED VALUE
# 21   JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 22   JAPANESE SPEAKING; ENGLISH SPEAK, READ & WRITE...  MASKED VALUE
# 23    JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 24    JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 25    JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 26    JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 27    JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 28   JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 29   JAPANESE SPEAKING; ENGLISH SPEAK, READ & WRITE...  MASKED VALUE
# ..                                                 ...           ...
# 229   JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 230  JAPANESE SPEAKING; ENGLISH SPEAK, READ & WRITE...  MASKED VALUE
# 231                    ENGLISH SPEAK, WRITE, READ ONLY  MASKED VALUE
# 232  JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 233                 NOT APPLICABLE (11 YRS. AND UNDER)  MASKED VALUE
# 234                   JAPANESE SPEAK, WRITE, READ ONLY  MASKED VALUE
# 235                    ENGLISH SPEAK, WRITE, READ ONLY  MASKED VALUE
# 236   JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 237   JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 238   JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 239   JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 240                 NOT APPLICABLE (11 YRS. AND UNDER)  MASKED VALUE
# 241                    ENGLISH SPEAK, WRITE, READ ONLY  MASKED VALUE
# 242  JAPANESE, ENGLISH AND OTHER LANGUAGE SPEAK, RE...  MASKED VALUE
# 243   JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 244   JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 245                   JAPANESE SPEAK, WRITE, READ ONLY  MASKED VALUE
# 246  JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 247   JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 248   JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 249   JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 250  JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 251                   JAPANESE SPEAK, WRITE, READ ONLY  MASKED VALUE
# 252   JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 253  JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 254  JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, RE...  MASKED VALUE
# 255   JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 256   JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 257   JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
# 258   JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE  MASKED VALUE
#
#                                     PRIMARY OCCUPATION  \
# 0                                      Retail Managers
# 1                                  Salesmen, Insurance
# 2                                  Salesmen, Insurance
# 3                                      Retail Managers
# 4                               Crop Specialty Farmers
# 5        Waiters and Waitresses, Except Private Family
# 6             Boarding-House and Lodging-House Keepers
# 7                                         Sales Clerks
# 8                             Stenographer and Typists
# 9                            Farm Managers and Foremen
# 10   Semiskilled Chauffeurs and Drivers, Bus, Taxi,...
# 11                                      Maids, General
# 12                                                 NaN
# 13                                        Sales Clerks
# 14                               Farm Hands, Vegetable
# 15                                                 NaN
# 16                                       Truck Farmers
# 17   Semiskilled Occupations in Laundering, Cleanin...
# 18   Semiskilled Chauffeurs and Drivers, Bus, Taxi,...
# 19                                       Fruit Farmers
# 20                                        Sales Clerks
# 21   Semiskilled Occupations in Laundering, Cleanin...
# 22                        Cooks, Except Private Family
# 23                                       Fruit Farmers
# 24                               Farm Hands, Vegetable
# 25                               Farm Hands, Vegetable
# 26                               Farm Hands, Vegetable
# 27                 Managerial and Official Occupations
# 28                                                 NaN
# 29                                   Farm Hands, Fruit
# ..                                                 ...
# 229          Teachers, Primary School and Kindergarten
# 230                                       Sales Clerks
# 231                   Nursery and Landscaping Laborers
# 232                      Hotel and Restaurant Managers
# 233                                                NaN
# 234               Nursery Operators and Flower Growers
# 235                             Clerks, General Office
# 236               Nursery Operators and Flower Growers
# 237                                     Undefined Code
# 238                                      Truck Farmers
# 239                                  Farm Hands, Fruit
# 240                                                NaN
# 241               Skilled Dressmakers and Seamstresses
# 242                                  Farm Hands, Fruit
# 243                                  Farm Hands, Fruit
# 244               Nursery Operators and Flower Growers
# 245            Semiskilled Sawmill Occupations, N.E.C.
# 246                                                NaN
# 247                                     Undefined Code
# 248                                    Retail Managers
# 249                                  Farm Hands, Fruit
# 250                                                NaN
# 251                   Nursery and Landscaping Laborers
# 252                                     Maids, General
# 253                               Semiskilled Routemen
# 254                                                NaN
# 255                              Farm Hands, Vegetable
# 256                                                NaN
# 257                         Social and Welfare Workers
# 258                                     Maids, General
#
#                                   SECONDARY OCCUPATION  \
# 0                                                  NaN
# 1                       Managers and Officials, N.E.C.
# 2                       Managers and Officials, N.E.C.
# 3                                            Designers
# 4                                   Wholesale Managers
# 5                                    Farm Hands, Fruit
# 6                                         Sales Clerks
# 7                                       Maids, General
# 8                                      Cooks, Domestic
# 9    Semiskilled Chauffeurs and Drivers, Bus, Taxi,...
# 10             Semiskilled Apprentices to Other Trades
# 11                                      Undefined Code
# 12                                                 NaN
# 13                                      Maids, General
# 14                                        Sales Clerks
# 15                                                 NaN
# 16                                                 NaN
# 17      Bookkeepers and Cashiers, Except Bank Cashiers
# 18   Skilled Inspectors, Scalers, and Graders, Logs...
# 19                                                 NaN
# 20                 Managerial and Official Occupations
# 21                                                 NaN
# 22                                                 NaN
# 23                      Managers and Officials, N.E.C.
# 24                                                 NaN
# 25                 Managerial and Official Occupations
# 26                                      Undefined Code
# 27                               Farm Hands, Vegetable
# 28                                                 NaN
# 29   Semiskilled Occupations in Manufacture of Misc...
# ..                                                 ...
# 229                   Clerical and Kindred Occupations
# 230                           Professional Occupations
# 231                                       Sales Clerks
# 232                                                NaN
# 233                                                NaN
# 234                                                NaN
# 235           Semiskilled Dressmakers and Seamstresses
# 236                                     Undefined Code
# 237                                 Wholesale Managers
# 238                                Farm Hands, Poultry
# 239  Semiskilled Occupations in Manufacture of Misc...
# 240                                                NaN
# 241                                     Maids, General
# 242                                                NaN
# 243  Semiskilled Occupations in Manufacture of Misc...
# 244  Semiskilled Chauffeurs and Drivers, Bus, Taxi,...
# 245                                                NaN
# 246                                                NaN
# 247                                                NaN
# 248  Unskilled Occupations in Canning and Preservin...
# 249                           Professional Occupations
# 250                                                NaN
# 251                                                NaN
# 252                                  Farm Hands, Fruit
# 253                   Nursery and Landscaping Laborers
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
# 258                                                NaN
#
#                                    TERTIARY OCCUPATION  \
# 0                                                  NaN
# 1                            Farm Managers and Foremen
# 2                            Farm Managers and Foremen
# 3                         Personal Service Occupations
# 4                                   Post Office Clerks
# 5                                                  NaN
# 6                                        Ship Stewards
# 7                                                  NaN
# 8        Maids and Housemen, Hotels, Restaurants, Etc.
# 9                                                  NaN
# 10      Skilled Mechanics and Repairmen, Motor Vehicle
# 11                                                 NaN
# 12                                                 NaN
# 13                               Farm Hands, Vegetable
# 14                Skilled Dressmakers and Seamstresses
# 15                                                 NaN
# 16                                                 NaN
# 17             Semiskilled Sawmill Occupations, N.E.C.
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                      Undefined Code
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29              Clerks and Kindred Occupations, N.E.C.
# ..                                                 ...
# 229                                                NaN
# 230                                                NaN
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
# 234                                                NaN
# 235                                     Maids, General
# 236                                                NaN
# 237                                                NaN
# 238  Semiskilled Chauffeurs and Drivers, Bus, Taxi,...
# 239                                                NaN
# 240                                                NaN
# 241         Teachers (Secondary School) and Principals
# 242                                                NaN
# 243                                     Undefined Code
# 244                   Clerical and Kindred Occupations
# 245                                                NaN
# 246                                                NaN
# 247                                                NaN
# 248                Managerial and Official Occupations
# 249                                                NaN
# 250                                                NaN
# 251                                                NaN
# 252                                                NaN
# 253                                                NaN
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
# 258                                                NaN
#
#                                 POTENTIAL OCCUPATION 1  \
# 0                           Social and Welfare Workers
# 1                                   Skilled Carpenters
# 2                                   Skilled Carpenters
# 3                Barbers, Beauticians, and Manicurists
# 4                  Managerial and Official Occupations
# 5                      Musicians and Teachers of Music
# 6       Skilled Mechanics and Repairmen, Motor Vehicle
# 7    Semiskilled Occupations in Manufacture of Knit...
# 8             Semiskilled Dressmakers and Seamstresses
# 9             Semiskilled Dressmakers and Seamstresses
# 10                                                 NaN
# 11            Semiskilled Dressmakers and Seamstresses
# 12                                                 NaN
# 13                     Musicians and Teachers of Music
# 14                     Musicians and Teachers of Music
# 15                     Musicians and Teachers of Music
# 16   Semiskilled Chauffeurs and Drivers, Bus, Taxi,...
# 17                                  Skilled Carpenters
# 18   Athletes, Sports Instructors, and Sports Offic...
# 19                  Inspectors, Public Service, N.E.C.
# 20                    Professional Occupations, N.E.C.
# 21                                       Photographers
# 22   Athletes, Sports Instructors, and Sports Offic...
# 23                             Fishermen and Oystermen
# 24   Semiskilled Mechanics and Repairmen, Motor Veh...
# 25   Athletes, Sports Instructors, and Sports Offic...
# 26                               Skilled Cabinetmakers
# 27               Laboratory Technicians and Assistants
# 28                                                 NaN
# 29      Skilled Pattern and Model Makers, Except Paper
# ..                                                 ...
# 229                                    Clerks, General
# 230                                                NaN
# 231               Semiprofessional Occupations, N.E.C.
# 232                  Library Assistants and Attendants
# 233                    Musicians and Teachers of Music
# 234                                                NaN
# 235  Semiskilled Occupations in Manufacture of Knit...
# 236                                      Photographers
# 237                                      Photographers
# 238                                     Farm Mechanics
# 239  Athletes, Sports Instructors, and Sports Offic...
# 240                                                NaN
# 241            Artists, Sculptors, and Teachers of Art
# 242                    Musicians and Teachers of Music
# 243  Skilled Tinsmiths, Coppersmiths, and Sheet Met...
# 244                             Clerks, General Office
# 245                                 Skilled Carpenters
# 246                                                NaN
# 247               Skilled Dressmakers and Seamstresses
# 248              Laboratory Technicians and Assistants
# 249                                 Commercial Artists
# 250                                                NaN
# 251  Semiskilled Occupations in Manufacture of Knit...
# 252                         Social and Welfare Workers
# 253                                    Poultry Farmers
# 254                                                NaN
# 255                           Stenographer and Typists
# 256           Semiskilled Dressmakers and Seamstresses
# 257                           Stenographer and Typists
# 258  Semiskilled Occupations in Manufacture of Knit...
#
#                                 POTENTIAL OCCUPATION 2 FILE NUMBER BLANK 1
# 0                  Buyers and Department Heads, Stores      414012   31171
# 1                                                  NaN      414345   51081
# 2                                                  NaN      414345   51081
# 3                                      Cooks, Domestic      407623   41151
# 4                                                  NaN      400632   31171
# 5                 Semiprofessional Occupations, N.E.C.      405330   21092
# 6                              Fishermen and Oystermen      408396   51121
# 7                                                  NaN      412640   31121
# 8    Unskilled Occupations in Manufacture of Leathe...      400663   41121
# 9                           Social and Welfare Workers      413598   31121
# 10                                                 NaN      405361   41121
# 11                            Stenographer and Typists      413159   21142
# 12                                                 NaN      403357   13001
# 13            Semiskilled Dressmakers and Seamstresses      403351   31122
# 14   Skillled Occupations in Manufacture of Knit Goods      403352   31142
# 15                                                 NaN      403354   11051
# 16                   Library Assistants and Attendants      413634   41122
# 17                                                 NaN      414573   51092
# 18                     Musicians and Teachers of Music      400665   31121
# 19                             Fishermen and Oystermen      404625   41152
# 20                Skilled Dressmakers and Seamstresses      412874   31151
# 21                                                 NaN      404304   52133
# 22                                                 NaN      412739   31111
# 23                                Hunters and Trappers      402821   51121
# 24        Skilled General Woodwork Occupations, N.E.C.      413731   41101
# 25                                      Farm Mechanics      411807   31121
# 26                                           Draftsmen      411808   21121
# 27                             Physicians and Surgeons      415052   31181
# 28                                                 NaN      406279   21091
# 29                                                 NaN      411499   31121
# ..                                                 ...         ...     ...
# 229  Athletes, Sports Instructors, and Sports Offic...      404817   41181
# 230                                                NaN      402360   31152
# 231                             Clerks, General Office      404398   41101
# 232  Attendants, Hospitals and Other Institutions, ...      411535   41121
# 233                                                NaN      406477   11052
# 234                                                NaN      415347   82124
# 235                                 Commercial Artists      415346   41122
# 236                            Fishermen and Oystermen      408604   41122
# 237                            Fishermen and Oystermen      408604   41122
# 238                            Fishermen and Oystermen      405793   41121
# 239                                                NaN      404286   31141
# 240                                                NaN      411766   11011
# 241                                                NaN      401033   41121
# 242  Athletes, Sports Instructors, and Sports Offic...      410980   21111
# 243                    Musicians and Teachers of Music      404219   21121
# 244                                                NaN      401183   41121
# 245                  Library Assistants and Attendants      413167   82084
# 246                                                NaN      413168   72084
# 247                           Stenographer and Typists      413169   21111
# 248                                      Photographers      414524   31152
# 249                           Stenographer and Typists      405975   21121
# 250                                                NaN      410598   21081
# 251                                                NaN      412466   72094
# 252       Skilled General Woodwork Occupations, N.E.C.      412847   31121
# 253                                                NaN      401023   31122
# 254                                                NaN      401675   21102
# 255                                 Post Office Clerks      414878   31121
# 256                           Stenographer and Typists      401803   21122
# 257                    Authors, Editors, and Reporters      414617   41181
# 258            Artists, Sculptors, and Teachers of Art      406440   31141
#
# [259 rows x 46 columns]

# %%
def num_occurrences(table, first_name, last_name):
    first_name_s = pd.Series([first_name] * len(table.index))
    last_name_s = pd.Series([last_name]*len(table.index))
    query = table[(table['FIRST NAME'] == first_name_s) &  (table['LAST NAME'] == last_name_s)]
    num_rows = len(query)
    return num_rows

duplicates = set()
for index, row in merged.iterrows():
    first_name, last_name = row['FIRST NAME'], row['LAST NAME']
    n_occurrences = num_occurrences(merged, row['FIRST NAME'], row['LAST NAME'])
    if n_occurrences > 1:
        duplicates.add((first_name, last_name, n_occurrences))
duplicates
# Out:
# {('AIKO', 'YAMAMOTO', 3),
#  ('FRANCES', 'MORIOKA', 2),
#  ('FRANK', 'FUJITA', 2),
#  ('FRANK', 'MATSUMOTO', 4),
#  ('FRANK', 'YAMAMOTO', 2),
#  ('GEORGE', 'DANZUKA', 4),
#  ('GEORGE', 'KATO', 2),
#  ('GEORGE', 'KUBO', 2),
#  ('GEORGE', 'MIYAI', 2),
#  ('GEORGE', 'NOMURA', 2),
#  ('GEORGE', 'SUMIDA', 2),
#  ('GEORGE', 'TAKAO', 3),
#  ('GEORGE', 'TAKETA', 3),
#  ('GEORGE', 'YASUI', 2),
#  ('HARRY', 'HAMADA', 2),
#  ('HIROSHI', 'KANEKO', 2),
#  ('HIROSHI', 'NAKAMURA', 3),
#  ('JOE', 'TOMITA', 2),
#  ('LILY', 'YAMASAKI', 2),
#  ('MARY', 'MARUYAMA', 2),
#  ('NOBORU', 'HONDA', 2),
#  ('PAUL', 'TAKAHASHI', 2),
#  ('TAKESHI', 'NAKAMURA', 2),
#  ('YOSHIKO', 'SUZUKI', 2),
#  ('YOSHIYE', 'FURUTA', 2)}

# %%
tulean_dispatch = Table.from_df(merged)
tulean_dispatch
# Out:
# Age  | RELOCATION PROJECT | Date of Departure | DESTINATION             | FIRST NAME | Gender | LAST NAME | Marital Status | Middle Name | Notes                                                      | Occupation            | Source               | Unnamed: 0 | MIDDLE INITIAL | ASSEMBLY CENTER      | LAST PERMANENT ADDRESS                                       | LAST PERMANENT ADDRESS STATE | LAST PERMANENT ADDRESS COUNTY | LAST PERMANENT ADDRESS POPULATION DENSITY                    | BIRTH PLACE OF PARENTS     | FATHERS OCCUPATION IN U.S.          | FATHERS OCCUPATION ABROAD  | TOTAL YEARS OF SCHOOLING IN JAPAN | YEARS OF SCHOOLING IN JAPAN | EDUCATIONAL DEGREES                     | YEAR OF FIRST ARRIVAL IN TERRITORIAL U.S. | TOTAL LENGTH OF TIME IN JAPAN         | NUMBER OF TIMES IN JAPAN    | AGE AT TIME IN JAPAN          | MILITARY AND NAVAL SERVICE, PUBLIC ASSISTANCE AND PENSIONS, PHYSICAL DEFECTS | INDIVIDUAL NUMBER | SEX AND MARITAL STATUS | RACE OF INDIVIDUAL AND SPOUSE        | YEAR OF BIRTH | BIRTH PLACE                 | ALIEN REGISTRATION NUMBER, SOCIAL SECURITY NUMBER AND JAPANESE LANGUAGE SCHOOL | HIGHEST GRADE COMPLETED OR GRADE ATTENDING | LANGUAGE                                                 | RELIGION     | PRIMARY OCCUPATION                            | SECONDARY OCCUPATION                                         | TERTIARY OCCUPATION                           | POTENTIAL OCCUPATION 1                               | POTENTIAL OCCUPATION 2                                       | FILE NUMBER | BLANK 1
# nan  | Tule Lake          | nan               | Rupert, Idaho           | TAKEO      | nan    | YOSHIHARA | nan            | nan         | Also mentioned in TD 5.4                                   | nan                   | Tulean Dispatch 5.1b | 957        | nan            | Pinedale             | TACOMA, WASHINGTON                                           | Pacific States - Washington  | PIERCE                        | 25,000 - 999,999                                             | Father=Japan, Mother=Japan | MANAGERIAL & OFFICIAL (EXCEPT FARM) | BLANK, UNKNOWN, NONE, DASH | NONE                              | NONE                        | BACHELORS-SOCIAL SCIENCES & MATHEMATICS | --                                        | NONE                                  | NONE-- NOT ATTENDING SCHOOL | NEVER IN JAPAN                | MASKED VALUE                                                                 | 19414A            | MALE SINGLE            | INDIVIDUAL-JAPANESE; NO SPOUSE       | 18            | Pacific States - Washington | HAS NEITHER A.R. NOR S. S. NUMBER AND HAS ATTENDED JAPANESE LANGUAGE SCHOOL    | COLLEGE 4 IN U.S.                          | JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE         | MASKED VALUE | Retail Managers                               | nan                                                          | nan                                           | Social and Welfare Workers                           | Buyers and Department Heads, Stores                          | 414012      | 31171
# nan  | Tule Lake          | nan               | New York, New York      | NOBORU     | nan    | HONDA     | nan            | nan         | Rochdale Institute                                         | Student               | Tulean Dispatch 5.2  | 156        | nan            | None                 | MARYSVILLE,  CALIFORNIA                                      | Pacific States - California  | YUBA                          | 5000 - 9999                                                  | Father=Japan, Mother=Japan | FARM OPERATORS & MANAGERS           | BLANK, UNKNOWN, NONE, DASH | NONE                              | NONE                        | NO DEGREE                               | --                                        | NONE                                  | NONE-- NOT ATTENDING SCHOOL | NEVER IN JAPAN                | MASKED VALUE                                                                 | 38600A            | MALE MARRIED           | INDIVIDUAL-JAPANESE; SPOUSE-JAPANESE | 11            | Pacific States - California | HAS NEITHER A.R. NOR S. S. NUMBER AND HAS ATTENDED JAPANESE LANGUAGE SCHOOL    | ELEMENTARY 8 IN U.S.                       | JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, READ & WRITE | MASKED VALUE | Salesmen, Insurance                           | Managers and Officials, N.E.C.                               | Farm Managers and Foremen                     | Skilled Carpenters                                   | nan                                                          | 414345      | 51081
# nan  | Tule Lake          | 7/5/1943          | Des Plaines, Illinois   | NOBORU     | nan    | HONDA     | nan            | nan         | nan                                                        | nan                   | Tulean Dispatch 5.93 | 156        | nan            | None                 | MARYSVILLE,  CALIFORNIA                                      | Pacific States - California  | YUBA                          | 5000 - 9999                                                  | Father=Japan, Mother=Japan | FARM OPERATORS & MANAGERS           | BLANK, UNKNOWN, NONE, DASH | NONE                              | NONE                        | NO DEGREE                               | --                                        | NONE                                  | NONE-- NOT ATTENDING SCHOOL | NEVER IN JAPAN                | MASKED VALUE                                                                 | 38600A            | MALE MARRIED           | INDIVIDUAL-JAPANESE; SPOUSE-JAPANESE | 11            | Pacific States - California | HAS NEITHER A.R. NOR S. S. NUMBER AND HAS ATTENDED JAPANESE LANGUAGE SCHOOL    | ELEMENTARY 8 IN U.S.                       | JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, READ & WRITE | MASKED VALUE | Salesmen, Insurance                           | Managers and Officials, N.E.C.                               | Farm Managers and Foremen                     | Skilled Carpenters                                   | nan                                                          | 414345      | 51081
# nan  | Tule Lake          | nan               | New York, New York      | FUMI       | nan    | SAKAMOTO  | nan            | nan         | Rochdale Institute; a letter of hers is conveyed in TD 5.5 | Student               | Tulean Dispatch 5.2  | 701        | nan            | Sacramento (Walerga) | SACRAMENTO, CALIFORNIA                                       | Pacific States - California  | SACRAMENTO                    | 25,000 - 999,999                                             | Father=Japan, Mother=Japan | MANAGERIAL & OFFICIAL (EXCEPT FARM) | BLANK, UNKNOWN, NONE, DASH | NONE                              | NONE                        | NO DEGREE                               | --                                        | NONE                                  | NONE--ATTENDING SCHOOL      | NEVER IN JAPAN                | MASKED VALUE                                                                 | 27323C            | FEMALE MARRIED         | INDIVIDUAL-JAPANESE; SPOUSE-WHITE    | 14            | Pacific States - California | HAS S.S. BUT NOT A.R. NUMBER AND HAS NOT ATTENDED JAPANESE LANGUAGE SCHOOL     | COLLEGE 2 IN U.S.                          | JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE         | MASKED VALUE | Retail Managers                               | Designers                                                    | Personal Service Occupations                  | Barbers, Beauticians, and Manicurists                | Cooks, Domestic                                              | 407623      | 41151
# nan  | Tule Lake          | nan               | New York, New York      | ROBERT     | nan    | OTA       | nan            | nan         | Rochdale Institute                                         | Student               | Tulean Dispatch 5.2  | 599        | Y              | None                 | DAVIS OR WINTERS, CALIFORNIA                                 | Pacific States - California  | YOLO                          | Incorporated cities of less than 2500 population All uni ... | Father=Japan, Mother=Japan | FARM OPERATORS & MANAGERS           | BLANK, UNKNOWN, NONE, DASH | NONE                              | NONE                        | BACHELORS-SOCIAL SCIENCES & MATHEMATICS | --                                        | NONE                                  | NONE-- NOT ATTENDING SCHOOL | NEVER IN JAPAN                | MASKED VALUE                                                                 | 37212A            | MALE SINGLE            | INDIVIDUAL-JAPANESE; NO SPOUSE       | 18            | Hawaii - Honolulu County    | HAS S.S. BUT NOT A.R. NUMBER AND HAS NOT ATTENDED JAPANESE LANGUAGE SCHOOL     | COLLEGE 4 IN U.S.                          | JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE         | MASKED VALUE | Crop Specialty Farmers                        | Wholesale Managers                                           | Post Office Clerks                            | Managerial and Official Occupations                  | nan                                                          | 400632      | 31171
# nan  | Tule Lake          | nan               | Ann Arbor, Michigan     | GEORGE     | nan    | SUMIDA    | nan            | nan         | nan                                                        | Gas Station Attendant | Tulean Dispatch 5.2  | 766        | H              | Sacramento (Walerga) | SACRAMENTO, CALIFORNIA                                       | Pacific States - California  | SACRAMENTO                    | 25,000 - 999,999                                             | Father=Japan, Mother=Japan | MANAGERIAL & OFFICIAL (EXCEPT FARM) | BLANK, UNKNOWN, NONE, DASH | NONE                              | NONE                        | NO DEGREE                               | nan                                       | 1 YEAR BUT LESS THAN 5 YEARS IN JAPAN | 1 TIME--ATTENDING SCHOOL    | BETWEEN AGES 0-9 & ALSO 10-19 | MASKED VALUE                                                                 | 28188C            | MALE SINGLE            | INDIVIDUAL-JAPANESE; NO SPOUSE       | 25            | Pacific States - California | HAS NEITHER A.R. NOR S. S. NUMBER AND HAS ATTENDED JAPANESE LANGUAGE SCHOOL    | HIGH SCHOOL 1 IN U.S.                      | JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, READ & WRITE | MASKED VALUE | Waiters and Waitresses, Except Private Family | Farm Hands, Fruit                                            | nan                                           | Musicians and Teachers of Music                      | Semiprofessional Occupations, N.E.C.                         | 405330      | 21092
# nan  | Tule Lake          | nan               | Ann Arbor, Michigan     | GEORGE     | nan    | SUMIDA    | nan            | nan         | nan                                                        | Gas Station Attendant | Tulean Dispatch 5.2  | 759        | M              | Sacramento (Walerga) | SACRAMENTO, CALIFORNIA                                       | Pacific States - California  | SACRAMENTO                    | 25,000 - 999,999                                             | Father=Japan, Mother=Japan | FARM OPERATORS & MANAGERS           | FARM OPERATORS & MANAGERS  | NONE                              | NONE                        | NO DEGREE                               | --                                        | NONE                                  | NONE-- NOT ATTENDING SCHOOL | NEVER IN JAPAN                | MASKED VALUE                                                                 | 28335G            | MALE MARRIED           | INDIVIDUAL-JAPANESE; SPOUSE-WHITE    | 12            | Pacific States - California | HAS S.S. BUT NOT A.R. NUMBER AND HAS NOT ATTENDED JAPANESE LANGUAGE SCHOOL     | HIGH SCHOOL 4 IN U.S.                      | JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE         | MASKED VALUE | Boarding-House and Lodging-House Keepers      | Sales Clerks                                                 | Ship Stewards                                 | Skilled Mechanics and Repairmen, Motor Vehicle       | Fishermen and Oystermen                                      | 408396      | 51121
# nan  | Tule Lake          | nan               | Camp Robinson, Arkansas | JOSIE      | nan    | YANAGAWA  | nan            | S.          | nan                                                        | nan                   | Tulean Dispatch 5.2  | 926        | S              | Pinedale             | SEATTLE, WASHINGTON                                          | Pacific States - Washington  | KING                          | 25,000 - 999,999                                             | Father=Japan, Mother=Japan | FARM OPERATORS & MANAGERS           | BLANK, UNKNOWN, NONE, DASH | NONE                              | NONE                        | NO DEGREE                               | --                                        | NONE                                  | NONE-- NOT ATTENDING SCHOOL | NEVER IN JAPAN                | MASKED VALUE                                                                 | 17060D            | FEMALE SINGLE          | INDIVIDUAL-JAPANESE; NO SPOUSE       | 20            | Pacific States - Washington | HAS S.S. BUT NOT A.R. NUMBER AND HAS ATTENDED JAPANESE LANGUAGE SCHOOL         | HIGH SCHOOL 4 IN U.S.                      | JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, READ & WRITE | MASKED VALUE | Sales Clerks                                  | Maids, General                                               | nan                                           | Semiskilled Occupations in Manufacture of Knit Goods | nan                                                          | 412640      | 31121
# nan  | Tule Lake          | March 22, 1943    | Caldwell, Idaho         | MIDORI     | nan    | FURUSHIRO | nan            | nan         | nan                                                        | nan                   | Tulean Dispatch 5.2  | 96         | nan            | None                 | DAVIS OR WINTERS, CALIFORNIA                                 | Pacific States - California  | YOLO                          | Incorporated cities of less than 2500 population All uni ... | Father=Japan, Mother=Japan | PROFESSIONAL & SEMI-PROFESSIONAL    | BLANK, UNKNOWN, NONE, DASH | NONE                              | NONE                        | NO DEGREE                               | --                                        | NONE                                  | NONE-- NOT ATTENDING SCHOOL | NEVER IN JAPAN                | MASKED VALUE                                                                 | 37253B            | FEMALE MARRIED         | INDIVIDUAL-JAPANESE; SPOUSE-JAPANESE | 16            | Mountain States - Colorado  | HAS S.S. BUT NOT A.R. NUMBER AND HAS NOT ATTENDED JAPANESE LANGUAGE SCHOOL     | HIGH SCHOOL 4 IN U.S.                      | JAPANESE SPEAKING; ENGLISH SPEAK, READ AND WRITE         | MASKED VALUE | Stenographer and Typists                      | Cooks, Domestic                                              | Maids and Housemen, Hotels, Restaurants, Etc. | Semiskilled Dressmakers and Seamstresses             | Unskilled Occupations in Manufacture of Leather Products ... | 400663      | 41121
# nan  | Tule Lake          | nan               | Palatine, Illinois      | YURI       | nan    | YAMAGIWA  | nan            | nan         | nan                                                        | nan                   | Tulean Dispatch 5.2  | 916        | nan            | Pinedale             | BOTHELL, REDMOND, KIRKLAND, DUVALL, ISSAQUAH, NORTH BEND ... | Pacific States - Washington  | KING                          | Incorporated cities of less than 2500 population All uni ... | Father=Japan, Mother=Japan | FARM OPERATORS & MANAGERS           | BLANK, UNKNOWN, NONE, DASH | NONE                              | NONE                        | NO DEGREE                               | --                                        | NONE                                  | NONE-- NOT ATTENDING SCHOOL | NEVER IN JAPAN                | MASKED VALUE                                                                 | 19948A            | FEMALE SINGLE          | INDIVIDUAL-JAPANESE; NO SPOUSE       | 21            | Pacific States - Washington | HAS NEITHER A.R. NOR S. S. NUMBER AND HAS ATTENDED JAPANESE LANGUAGE SCHOOL    | HIGH SCHOOL 4 IN U.S.                      | JAPANESE SPEAK, WRITE, READ; ENGLISH SPEAK, READ & WRITE | MASKED VALUE | Farm Managers and Foremen                     | Semiskilled Chauffeurs and Drivers, Bus, Taxi, Truck, an ... | nan                                           | Semiskilled Dressmakers and Seamstresses             | Social and Welfare Workers                                   | 413598      | 31121
# ... (249 rows omitted)

# %%
# Grouping by first
get_first = lambda x: x[0]
tulean_dispatch= tulean_dispatch.group('FIRST NAME', collect = get_first).group('LAST NAME', collect = get_first)
# Get Columns of Interest
tulean_dispatch = tulean_dispatch.select(['FIRST NAME', 'LAST NAME', 'RELOCATION PROJECT', 'LAST PERMANENT ADDRESS STATE', 'LAST PERMANENT ADDRESS COUNTY', 'ASSEMBLY CENTER', 'DESTINATION'])

# %%
coords = Table.read_table('tuleandispatch_coordinates.csv')
# Group locations
coords = coords.group('Location', collect = lambda x: x[0])
# Join Coordinates and locations
def process_coords(coords):
    return list([float(coord) for coord in coords.split(',')])
locations = ['RELOCATION PROJECT', 'DESTINATION']
for name in locations:
    tulean_dispatch = tulean_dispatch.join(name, coords, 'Location')
    tulean_dispatch[name + ' COORDS'] = tulean_dispatch.apply(process_coords, 'Lat,Long')
    tulean_dispatch = tulean_dispatch.drop(['Lat,Long', 'Notes'])

# %%
tulean_dispatch
# Out:
# DESTINATION                     | RELOCATION PROJECT | FIRST NAME | LAST NAME | LAST PERMANENT ADDRESS STATE | LAST PERMANENT ADDRESS COUNTY | ASSEMBLY CENTER      | RELOCATION PROJECT COORDS | DESTINATION COORDS
# Ann Arbor, Michigan             | Tule Lake          | GEORGE     | SUMIDA    | Pacific States - California  | SACRAMENTO                    | Sacramento (Walerga) | [  41.9688 -121.5681]     | [42.281389, -83.748333]
# Baldwin, Kansas                 | Tule Lake          | KATE       | KYONO     | Pacific States - Oregon      | MARION                        | None                 | [  41.9688 -121.5681]     | [38.7775, -95.1875]
# Boise, Idaho                    | Tule Lake          | JANE       | HAMADA    | Pacific States - California  | SANTA CRUZ                    | Marysville (Arboga)  | [  41.9688 -121.5681]     | [43.6187, -116.2146]
# Boise, Idaho                    | Tule Lake          | YOSHIMI    | ISHIMOTO  | Pacific States - California  | SACRAMENTO                    | Sacramento (Walerga) | [  41.9688 -121.5681]     | [43.6187, -116.2146]
# Boise, Idaho                    | Tule Lake          | ELAINE     | TSUMURA   | nan                          | nan                           | None                 | [  41.9688 -121.5681]     | [43.6187, -116.2146]
# CLEVELAND, OHIO                 | Tule Lake          | KIKUJI     | RYUGO     | Pacific States - California  | SACRAMENTO                    | Sacramento (Walerga) | [  41.9688 -121.5681]     | [41.505493, -81.68129]
# Caldwell, Idaho                 | Tule Lake          | MIDORI     | FURUSHIRO | Pacific States - California  | YOLO                          | None                 | [  41.9688 -121.5681]     | [43.658333, -116.680278]
# Camp Granada - Amacha, Colorado | Tule Lake          | FUSAKO     | TEKAWA    | Pacific States - California  | YUBA                          | None                 | [  41.9688 -121.5681]     | [38.064722, -102.311111]
# Camp Robinson, Arkansas         | Tule Lake          | JOSIE      | YANAGAWA  | Pacific States - Washington  | KING                          | Pinedale             | [  41.9688 -121.5681]     | [34.85, -92.300278]
# Camp Savage, Minnesota          | Tule Lake          | SARA       | TANIGAWA  | Pacific States - California  | PLACER                        | Sacramento (Walerga) | [  41.9688 -121.5681]     | [44.783333, -93.333333]
# ... (102 rows omitted)

# %%
def get_from_to_coords(table, from_location, to_location):
    result = table.select([from_location + ' COORDS', to_location + ' COORDS'])
    result.relabel(from_location + ' COORDS', 'from')
    result.relabel(to_location + ' COORDS', 'to')
    return result
relocation_to_destination = get_from_to_coords(tulean_dispatch, 'RELOCATION PROJECT', 'DESTINATION')
relocation_to_destination
# Out:
# ['RELOCATION PROJECT COORDS', 'DESTINATION COORDS']

# %%
relocation_to_destination['from'][0]
# Out:
# array([  41.9688, -121.5681])

# %%
import folium
from IPython.display import HTML

def display(m, height=500):
    """Takes a folium instance and embed HTML."""
    m._build_map()
    srcdoc = m.HTML.replace('"', '&quot;')
    embed = HTML('<iframe srcdoc="{0}" '
                 'style="width: 100%; height: {1}px; '
                 'border: none"></iframe>'.format(srcdoc, height))
    return embed


m = folium.Map(location=[39.828175, -98.5795], zoom_start=4, tiles='Stamen Terrain')
# Create the map with the appoximate location of San Andreas Fault
for from_to in relocation_to_destination.rows:
    #from_to = folium.PolyLine(locations=list(row),weight=2,color = 'red')
    m.line(from_to, line_weight=3, line_color = '#a3c6ff', line_opacity = 0.7)
display(m)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_64f635e89cb942a6a4e6c2645270da64&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Map tiles by <a href=&quot;http://stamen.com&quot;>Stamen Design</a>, under <a href=&quot;http://creativecommons.org/licenses/by/3.0&quot;>CC BY 3.0</a>. Data by <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a>, under <a href=&quot;http://creativecommons.org/licenses/by-sa/3.0&quot;>CC BY SA</a>.'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_64f635e89cb942a6a4e6c2645270da64', {
#                                        center:[39.828175, -98.5795],
#                                        zoom: 4,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#
#
#
#
#       var latLngs = [ [41.9688, -121.5681],  [42.281389, -83.748333], ];
# var line_1 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_1);
#
#       var latLngs = [ [41.9688, -121.5681],  [38.7775, -95.1875], ];
# var line_2 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_2);
#
#       var latLngs = [ [41.9688, -121.5681],  [43.6187, -116.2146], ];
# var line_3 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_3);
#
#       var latLngs = [ [41.9688, -121.5681],  [43.6187, -116.2146], ];
# var line_4 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_4);
#
#       var latLngs = [ [41.9688, -121.5681],  [43.6187, -116.2146], ];
# var line_5 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_5);
#
#       var latLngs = [ [41.9688, -121.5681],  [41.505493, -81.68129], ];
# var line_6 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_6);
#
#       var latLngs = [ [41.9688, -121.5681],  [43.658333, -116.680278], ];
# var line_7 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_7);
#
#       var latLngs = [ [41.9688, -121.5681],  [38.064722, -102.311111], ];
# var line_8 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_8);
#
#       var latLngs = [ [41.9688, -121.5681],  [34.85, -92.300278], ];
# var line_9 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_9);
#
#       var latLngs = [ [41.9688, -121.5681],  [44.783333, -93.333333], ];
# var line_10 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_10);
#
#       var latLngs = [ [41.9688, -121.5681],  [31.187778, -89.199167], ];
# var line_11 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_11);
#
#       var latLngs = [ [41.9688, -121.5681],  [nan, ], ];
# var line_12 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_12);
#
#       var latLngs = [ [41.9688, -121.5681],  [41.8781, -87.6298], ];
# var line_13 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_13);
#
#       var latLngs = [ [41.9688, -121.5681],  [41.8781, -87.6298], ];
# var line_14 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_14);
#
#       var latLngs = [ [41.9688, -121.5681],  [41.8781, -87.6298], ];
# var line_15 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_15);
#
#       var latLngs = [ [41.9688, -121.5681],  [41.8781, -87.6298], ];
# var line_16 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_16);
#
#       var latLngs = [ [41.9688, -121.5681],  [41.8781, -87.6298], ];
# var line_17 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_17);
#
#       var latLngs = [ [41.9688, -121.5681],  [41.8781, -87.6298], ];
# var line_18 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_18);
#
#       var latLngs = [ [41.9688, -121.5681],  [41.8781, -87.6298], ];
# var line_19 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_19);
#
#       var latLngs = [ [41.9688, -121.5681],  [41.8781, -87.6298], ];
# var line_20 = L.polyline(latLngs,{
# color: '#a3c6ff',
# weight: 3,
# opacity: 0.7,
# });
#
#       map.addLayer(line_20);
#
#       var latLngs = [ [41.9688, -121.5681],  [41.8781, -87.6298], ];
# v

# %% [markdown]
# https://github.com/jwass/folium/commit/865eda47ddcec937ab22fa39503cebb11a754a69#commitcomment-6469995

# %%
process_coords(coords.where('Location', 'Tule Lake')['Lat,Long'][0])
# Out:
# [41.9688, -121.5681]

# %%
dir(folium.Map)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_auto_bounds',
#  '_build_map',
#  '_popup_render',
#  '_repr_html_',
#  'add_layers_to_map',
#  'add_tile_layer',
#  'add_wms_layer',
#  'circle_marker',
#  'click_for_marker',
#  'create_map',
#  'display',
#  'fit_bounds',
#  'geo_json',
#  'lat_lng_popover',
#  'line',
#  'multiline',
#  'polygon_marker',
#  'simple_marker']
